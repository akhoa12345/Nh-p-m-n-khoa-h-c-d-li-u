# %% [markdown]
# <div style="text-align: center; background-color: #559cff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Lab 02 - Introduction To Data Science @ FIT-HCMUS, VNU-HCM 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #b1d1ff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 4.0 - Data modelling
# </div>

# %% [markdown]
# This section for bouns, you might need to use some basic Machine Learning algorithms to answer some questions that in cases of regression, and classification. In this scope of this subject, highly recommend you use `scikit-learn` (instead of implement once again these algorithms)

# %% [markdown]
# ## Import

# %%
# YOUR CODE HERE (OPTION) 
import pandas as pd
import matplotlib.pyplot as plt
# If you need other libraries, you can import them here

# %% [markdown]
# ## Data preparation

# %%
# YOUR CODE HERE (OPTION) 
df_process = pd.read_csv('../data/processed/19120548_asia_processed.csv')
df = df_process.copy()

# %%
# YOUR CODE HERE (OPTION) 
transformed_data = pd.get_dummies(df[['Total Population', 'Female Population', 'Male Population',
       'Birth Rate', 'Death Rate', 'Compulsory Education Dur.',
       'Employment in Industry(%)', 'Employment in Agriculture(%)',
       'Female Employment in Agriculture(%)',
       'Female Employment in Industry(%)', 'Unemployment(%)', 'GDP in USD',
       'National Income per Capita', 'Net income from Abroad',
       'Agriculture value added(in USD)',
       'Electric Power Consumption(kWH per capita)',
       'Renewable Energy Consumption (%)', 'Fossil Fuel Consumption (%)',
        'Female life expectancy ',
       'School enrollment, primary', 'School enrollment, tertiary',
       'Primary completion rate', 'Year', 'Country']])
transformed_data
# Out:
#       Total Population  Female Population  Male Population  Birth Rate  \
# 0           41128771.0         20362329.0       20766442.0   20.700378
# 1           40099462.0         19844584.0       20254878.0   35.842000
# 2           38972230.0         19279929.0       19692301.0   36.051000
# 3           37769499.0         18679090.0       19090409.0   36.466000
# 4           36686784.0         18136922.0       18549862.0   36.927000
# ...                ...                ...              ...         ...
# 1311        18114552.0          8986446.0        9128106.0   41.105000
# 1312        17608133.0          8739457.0        8868676.0   41.478000
# 1313        17108681.0          8495862.0        8612819.0   42.498000
# 1314        16614326.0          8254738.0        8359588.0   43.273000
# 1315        16103339.0          8005372.0        8097967.0   46.071000
#
#       Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# ...

# %%
x_data = transformed_data.values
y_data = df['Male life expectancy'].values

# %% [markdown]
# ## Training model: LinearRegression

# %%
# YOUR CODE HERE (OPTION) 
from sklearn.model_selection import train_test_split
x_data_train, x_data_test, y_data_train, y_data_test = train_test_split(x_data, y_data,test_size=0.2,random_state=1 )

# %%
from sklearn.linear_model import LinearRegression

lm = LinearRegression()
lm.fit(x_data_train, y_data_train)

Y_pred = lm.predict(x_data_test)

plt.scatter(y_data_test, Y_pred)
plt.xlabel("Value: $Y_i$")
plt.ylabel("Predicted Value: $\hat{Y}_i$")
plt.title("Value vs Value prices: $Y_i$ vs $\hat{Y}_i$")
# Out:
# Text(0.5, 1.0, 'Value vs Value prices: $Y_i$ vs $\\hat{Y}_i$')

# %% [markdown]
# - Em Sử dụng LinearRegression để dự đoán 'Male life expectancy' dựa theo các trường còn lại
# - Kết quả cho thấy kết quả dự đoán có độ chính xác cao

# %% [markdown]
# ## Training model: SVM

# %%
df_process = pd.read_csv('../data/processed/19120548_asia_processed.csv')
df = df_process.copy()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df
# Out:
#       Total Population  Female Population  Male Population  Birth Rate  \
# 0           41128771.0         20362329.0       20766442.0   20.700378
# 1           40099462.0         19844584.0       20254878.0   35.842000
# 2           38972230.0         19279929.0       19692301.0   36.051000
# 3           37769499.0         18679090.0       19090409.0   36.466000
# 4           36686784.0         18136922.0       18549862.0   36.927000
# ...                ...                ...              ...         ...
# 1311        18114552.0          8986446.0        9128106.0   41.105000
# 1312        17608133.0          8739457.0        8868676.0   41.478000
# 1313        17108681.0          8495862.0        8612819.0   42.498000
# 1314        16614326.0          8254738.0        8359588.0   43.273000
# 1315        16103339.0          8005372.0        8097967.0   46.071000
#
#       Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# ...

# %%
# transformed_data[['Total Population', 'Female Population', 'Male Population',
#        'Birth Rate', 'Death Rate', 'Compulsory Education Dur.',
#        'Employment in Industry(%)', 'Employment in Agriculture(%)',
#        'Female Employment in Agriculture(%)',
#        'Female Employment in Industry(%)', 'Unemployment(%)', 'GDP in USD',
#        'National Income per Capita', 'Net income from Abroad',
#        'Agriculture value added(in USD)',
#        'Electric Power Consumption(kWH per capita)',
#        'Renewable Energy Consumption (%)', 'Fossil Fuel Consumption (%)',
#        'Male life expectancy', 'Female life expectancy ',
#        'School enrollment, primary', 'School enrollment, tertiary',
#        'Primary completion rate', 'Year']] = scaler.fit_transform(transformed_data[['Total Population', 'Female Population', 'Male Population',
#        'Birth Rate', 'Death Rate', 'Compulsory Education Dur.',
#        'Employment in Industry(%)', 'Employment in Agriculture(%)',
#        'Female Employment in Agriculture(%)',
#        'Female Employment in Industry(%)', 'Unemployment(%)', 'GDP in USD',
#        'National Income per Capita', 'Net income from Abroad',
#        'Agriculture value added(in USD)',
#        'Electric Power Consumption(kWH per capita)',
#        'Renewable Energy Consumption (%)', 'Fossil Fuel Consumption (%)',
#        'Male life expectancy', 'Female life expectancy ',
#        'School enrollment, primary', 'School enrollment, tertiary',
#        'Primary completion rate', 'Year']])

# %%
transformed_data = pd.get_dummies(df[['Total Population', 'Female Population', 'Male Population',
       'Birth Rate', 'Death Rate', 'Compulsory Education Dur.',
       'Employment in Industry(%)', 'Employment in Agriculture(%)',
       'Female Employment in Agriculture(%)',
       'Female Employment in Industry(%)', 'Unemployment(%)', 'GDP in USD',
       'National Income per Capita', 'Net income from Abroad',
       'Agriculture value added(in USD)',
       'Electric Power Consumption(kWH per capita)',
       'Renewable Energy Consumption (%)', 'Fossil Fuel Consumption (%)',
        'Male life expectancy', 'Female life expectancy ',
       'School enrollment, primary', 'School enrollment, tertiary',
       'Primary completion rate', 'Year']])
transformed_data
# Out:
#       Total Population  Female Population  Male Population  Birth Rate  \
# 0           41128771.0         20362329.0       20766442.0   20.700378
# 1           40099462.0         19844584.0       20254878.0   35.842000
# 2           38972230.0         19279929.0       19692301.0   36.051000
# 3           37769499.0         18679090.0       19090409.0   36.466000
# 4           36686784.0         18136922.0       18549862.0   36.927000
# ...                ...                ...              ...         ...
# 1311        18114552.0          8986446.0        9128106.0   41.105000
# 1312        17608133.0          8739457.0        8868676.0   41.478000
# 1313        17108681.0          8495862.0        8612819.0   42.498000
# 1314        16614326.0          8254738.0        8359588.0   43.273000
# 1315        16103339.0          8005372.0        8097967.0   46.071000
#
#       Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# ...

# %%
x_data = transformed_data.values
y_data = df['Country'].values

# %%
from sklearn.model_selection import train_test_split
x_data_train, x_data_test, y_data_train, y_data_test = train_test_split(x_data, y_data,test_size=0.2,random_state=1 )

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(x_data_train, y_data_train)

#Predict the response for test dataset
y_pred = clf.predict(x_data_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_data_test, y_pred))
